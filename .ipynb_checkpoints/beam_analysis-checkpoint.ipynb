# %% [markdown]
# # Beam analysis
#
# The class below calculates the bending moment and shear forces for the beam. The input is the span, followed by a 2 dimension list. Each row of the list is a loading. The loading list elements are the start, end and load magnitude for the 0, 1 and indices. For a general UDL the load is the load per meter. For a point load, the start and end positions are set the same to represent the position of the point load and the load is the magitude of the point load.

# %%
from simple_beam_analysis import *

# %%
test = Beam(4, [[0,4,1.5], [2,2,5]])
test.force_diagram()
